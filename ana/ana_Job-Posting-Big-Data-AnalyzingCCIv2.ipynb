# %% [markdown]
# https://medium.com/swlh/web-scraping-python-requests-and-beautifulsoup-45d5f48f5a1
#
# https://sparkbyexamples.com/spark/spark-read-text-file-rdd-dataframe/
#
# https://medium.com/swlh/text2sql-in-spark-nlp-converting-natural-language-questions-to-sql-queries-on-scale-6ae9a9061d74
#
# https://www.oreilly.com/library/view/learning-spark-2nd/9781492050032/ch04.html

# %%
#!python -m pip install html2text

# %%
#!python -m pip install mistletoe

# %% [markdown]
# https://github.com/webrecorder/warcio

# %%
#!pip install warcio

# %%
#!python -m pip install cdx_toolkit

# %%
#%load_ext autoreload
#%autoreload 2

# %% [markdown]
# Run the cell below to import everything necessary for this analysis.

# %%
import json
import sys
import os.path
import re
import logging
import pandas as pd
import requests
import warcio
import mistletoe
import cdx_toolkit
import zlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from warcio import ArchiveIterator
from contextlib import closing
from html2text import HTML2Text
from bs4 import BeautifulSoup
from pathlib import Path
from IPython.display import HTML as HTML_raw, display
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE
from nltk.tokenize import word_tokenize
np.random.seed(0)

# %% [markdown]
# # Our corpus
#
# In this analysis, we'll be working with alomost 100k different documents, each containing one single job AD.
#
# These job AD plain text files are contained within the `\c\Users\renjm\Job-Posting-Big-Data\ana\dat\100k_jobADs` subdirectory, contained within the same folder as this analysis. Each job AD is stored in a single file, with files ranging from `1_2021JAN_jobAD.txt` to `99422_2021JAN_jobAD.txt`.
#
# To make it easy to read in all of the documents, use a list comprehension to create a list containing the name of every single job AD plain text file below.

# %%
filesList = []
n_0 = 1
n_1 = 100000
for i in range(n_0, n_1):
    filepath = './dat/100k_jobADs/'+str(i)+'_2021JAN_jobAD.txt'
    if (os.path.exists(filepath)):
        filesList.append(str(i)+'_2021JAN_jobAD.txt')

print(filesList)
# Out:
# ['1_2021JAN_jobAD.txt', '11_2021JAN_jobAD.txt', '12_2021JAN_jobAD.txt', '21_2021JAN_jobAD.txt', '22_2021JAN_jobAD.txt', '23_2021JAN_jobAD.txt', '27_2021JAN_jobAD.txt', '28_2021JAN_jobAD.txt', '33_2021JAN_jobAD.txt', '34_2021JAN_jobAD.txt', '39_2021JAN_jobAD.txt', '41_2021JAN_jobAD.txt', '42_2021JAN_jobAD.txt', '45_2021JAN_jobAD.txt', '49_2021JAN_jobAD.txt', '53_2021JAN_jobAD.txt', '54_2021JAN_jobAD.txt', '55_2021JAN_jobAD.txt', '56_2021JAN_jobAD.txt', '62_2021JAN_jobAD.txt', '65_2021JAN_jobAD.txt', '69_2021JAN_jobAD.txt', '74_2021JAN_jobAD.txt', '84_2021JAN_jobAD.txt', '87_2021JAN_jobAD.txt', '91_2021JAN_jobAD.txt', '92_2021JAN_jobAD.txt', '96_2021JAN_jobAD.txt', '108_2021JAN_jobAD.txt', '115_2021JAN_jobAD.txt', '116_2021JAN_jobAD.txt', '117_2021JAN_jobAD.txt', '118_2021JAN_jobAD.txt', '121_2021JAN_jobAD.txt', '124_2021JAN_jobAD.txt', '125_2021JAN_jobAD.txt', '129_2021JAN_jobAD.txt', '131_2021JAN_jobAD.txt', '132_2021JAN_jobAD.txt', '134_2021JAN_jobAD.txt', '135_2021JAN_jobAD.txt', '147_2021JAN_jobAD.txt', '153_2021JAN_jobAD.txt', '156_2021JAN_jobAD.txt', '164_2021JAN_jobAD.txt', '168_2021JAN_jobAD.txt', '169_2021JAN_jobAD.txt', '176_2021JAN_jobAD.txt', '177_2021JAN_jobAD.txt', '178_2021JAN_jobAD.txt', '182_2021JAN_jobAD.txt', '183_2021JAN_jobAD.txt', '184_2021JAN_jobAD.txt', '185_2021JAN_jobAD.txt', '192_2021JAN_jobAD.txt', '194_2021JAN_jobAD.txt', '195_2021JAN_jobAD.txt', '200_2021JAN_jobAD.txt', '201_2021JAN_jobAD.txt', '203_2021JAN_jobAD.txt', '204_2021JAN_jobAD.txt', '206_2021JAN_jobAD.txt', '209_2021JAN_jobAD.txt', '210_2021JAN_jobAD.txt', '213_2021JAN_jobAD.txt', '218_2021JAN_jobAD.txt', '221_2021JAN_jobAD.txt', '223_2021JAN_jobAD.txt', '227_2021JAN_jobAD.txt', '229_2021JAN_jobAD.txt', '233_2021JAN_jobAD.txt', '234_2021JAN_jobAD.txt', '239_2021JAN_jobAD.txt', '240_2021JAN_jobAD.txt', '243_2021JAN_jobAD.txt', '244_2021JAN_jobAD.txt', '247_2021JAN_jobAD.txt', '248_2021JAN_jobAD.txt', '253_2021JAN_jobAD.txt', '254_2021JAN_jobAD.txt', '255_2021JAN_jobAD.txt', '266_2021JAN_jobAD.txt', '268_2021JAN_jobAD.txt', '277_2021JAN_jobAD.txt', '285_2021JAN_jobAD.txt', '286_2021JAN_jobAD.txt', '293_2021JAN_jobAD.txt', '294_2021JAN_jobAD.txt', '296_2021JAN_jobAD.txt', '298_2021JAN_jobAD.txt', '301_2021JAN_jobAD.txt', '309_2021JAN_jobAD.txt', '310_2021JAN_jobAD.txt', '312_2021JAN_jobAD.txt', '323_2021JAN_jobAD.txt', '327_2021JAN_jobAD.txt', '332_2021JAN_jobAD.txt', '334_2021JAN_jobAD.txt', '344_2021JAN_jobAD.txt', '345_2021JAN_jobAD.txt', '348_2021JAN_jobAD.txt', '352_2021JAN_jobAD.txt', '356_2021JAN_jobAD.txt', '357_2021JAN_jobAD.txt', '360_2021JAN_jobAD.txt', '362_2021JAN_jobAD.txt', '364_2021JAN_jobAD.txt', '365_2021JAN_jobAD.txt', '367_2021JAN_jobAD.txt', '368_2021JAN_jobAD.txt', '373_2021JAN_jobAD.txt', '376_2021JAN_jobAD.txt', '378_2021JAN_jobAD.txt', '380_2021JAN_jobAD.txt', '381_2021JAN_jobAD.txt', '384_2021JAN_jobAD.txt', '385_2021JAN_jobAD.txt', '388_2021JAN_jobAD.txt', '390_2021JAN_jobAD.txt', '391_2021JAN_jobAD.txt', '394_2021JAN_jobAD.txt', '398_2021JAN_jobAD.txt', '399_2021JAN_jobAD.txt', '403_2021JAN_jobAD.txt', '405_2021JAN_jobAD.txt', '410_2021JAN_jobAD.txt', '415_2021JAN_jobAD.txt', '426_2021JAN_jobAD.txt', '430_2021JAN_jobAD.txt', '438_2021JAN_jobAD.txt', '440_2021JAN_jobAD.txt', '445_2021JAN_jobAD.txt', '449_2021JAN_jobAD.txt', '450_2021JAN_jobAD.txt', '453_2021JAN_jobAD.txt', '458_2021JAN_jobAD.txt', '460_2021JAN_jobAD.txt', '463_2021JAN_jobAD.txt', '464_2021JAN_jobAD.txt', '465_2021JAN_jobAD.txt', '466_2021JAN_jobAD.txt', '475_2021JAN_jobAD.txt', '482_2021JAN_jobAD.txt', '502_2021JAN_jobAD.txt', '504_2021JAN_jobAD.txt', '506_2021JAN_jobAD.txt', '510_2021JAN_jobAD.txt', '515_2021JAN_jobAD.txt', '516_2021JAN_jobAD.txt', '518_2021JAN_jobAD.txt', '520_2021JAN_jobAD.txt', '521_2021JAN_jobAD.txt', '527_2021JAN_jobAD.txt', '532_2021JAN_jobAD.txt', '535_2021JAN_jobAD.txt', '539_2021JAN_jobAD.txt', '543_2021JAN_jobAD.txt', '544_2021JAN_jobAD.txt', '547_2021JAN_jobAD.txt', '550_2021JAN_jobAD.txt', '551_2021JAN_jobAD.txt', '55 ...

# %% [markdown]
# next, create an empty DataFrame called `jobads_df`. As we read in job ads and store and clean them, we'll store them in this DataFrame.

# %%
jobads_df = pd.DataFrame()

# %% [markdown]
# next, let's import one job AD to see what our text looks like so that we can make sure we clean and tokenize it correctly.
#
# read in and print out the `job description` from `11_2021JAN_jobAD.txt`. Use vanilla Python, no pandas needed.
#
# 93148 (113), 59721 (107)

# %%
filepick = './dat/100k_jobADs/85473_2021JAN_jobAD.txt' 
with open(filepick, encoding='utf-8', errors='ignore') as f:
    test_jobad = f.readlines()
    print(test_jobad)
# Out:
# ['Workopolis Logo \n', ' Job Title, Keywords \n', ' City, Province \n', ' Menu \n', ' \n', ' Browse Jobs \n', ' Advanced Job Search \n', ' \n', ' \n', ' Français \n', ' \n', ' \n', ' \n', ' Post a job \n', ' Department Manager \n', ' Walmart Canada \n', ' __Richmond Hill, ON \n', ' Apply Now \n', ' LEADER, COACH, TEAM PLAYER—ALL ROLLED INTO ONE. \n', ' It takes a special kind of person to be a Department Manager at Walmart—because we’re every bit as committed to our team culture as we are to our customers. No matter the department, our Managers are friendly, confident communicators who know how to get the best out of their team—and they’ve got the leadership skills to make people want to perform their best. We’ll let you in on a secret: we even love and appreciate a bit of a competitive spirit… especially when it comes to hitting new milestones for our charitable initiatives and giving back to our communities. \n', ' The ability to engage and inspire your team to be better than they were yesterday, every single day? That’s a skill worth celebrating. Whether it’s motivating their team, providing recognition for great work, or ‘WOWing’ our customers… our Department Managers provide leadership right where the action is. And they wouldn’t have it any other way. \n', ' Our stellar team is seeking Managers with the following traits: \n', ' \n', ' Positive attitude \n', ' Confident leader \n', ' Great listening skills \n', ' Strong communication \n', ' Friendly demeanor \n', ' Inquisitive mind \n', ' Energetic \n', ' Outgoing \n', ' Welcoming \n', ' Motivated \n', ' Happy to help! \n', ' \n', ' At Walmart, every role matters—in every department. We’re seeking Department Managers who take pride in what they do and want to inspire others to be their best. \n', ' If you love people and want to work with a winning team that sees every customer as the unique, valued individual that they are, then we can’t wait to meet you. Realize your potential with Walmart—apply today. \n', ' Department Manager roles: \n', ' \n', ' Lead Customer Service Manager \n', ' Meat Department Manager \n', ' Produce Department Manager \n', ' Health & Wellness Manager \n', ' Customer Value Department Manager \n', ' Fashion Merchandiser Department Manager \n', ' Day/Evening Fulfillment Department Manager \n', ' \n', ' Qualifications: \n', ' \n', ' A great attitude \n', ' Willingness to lead \n', ' Attention to detail, so the store always looks great \n', ' Confidence handling real responsibility \n', ' Willingness to help solve problems \n', ' Your winning smile \n', ' Yes, that smile you already have \n', ' Seriously, it’s a great smile. Look in the mirror. \n', ' See? We told you so! \n', ' \n', ' Walmart Canada is one of Canada’s largest employers and is ranked as one of the country’s top 10 most influential brands… but what really sets us apart in the industry is our incredible team. \n', ' We’re committed to supporting our communities and supporting one another, and those values have cultivated a culture where everyone is welcome and each team member feels they truly belong. \n', ' Whether you’re looking for opportunities to grow your career long-term, or simply seeking a great place to work part-time, this is that place. \n', ' Minimum Qualifications...Outlined below are the required minimum qualifications for this position. If none are listed, there are no minimum qualifications. \n', ' Age - 16 or older \n', ' Preferred Qualifications...Outlined below are the optional preferred qualifications for this position. If none are listed, there are no preferred qualifications. \n', ' Walmart will accommodate the disability-related needs of applicants and associates as required by law. \n', " What you'll do... \n", 'LEADER, COACH, TEAM PLAYER—ALL ROLLED INTO ONE. It takes a special kind of person to be a Department Manager at Walmart—because we’re every bit as committed to our team culture as we are to our customers. No matter the department, our Managers are friend ...

# %% [markdown]
# ## Tokenizing our Data
#
# Before we can create a bag of words or vectorize each document, we need to clean it up and split each job AD into an array of individual words. Computers are very particular about strings. If we tokenized our data in its current state, we would run into the following problems:
#
# * Counting things that aren't actually words.
# * Punctuation and capitalization would mess up our word counts. To the Python interpreter, `love`, `Love`, `Love?`, and `Love\n` are all unique words, and would all be counted separately. We need to remove punctuation and capitalization, so that all words will be counted correctly.
#
# Tokenization is pretty tedious if we handle it manually, and would probably make use of `regular expressions`. In order to keep this lab moving, we'll use a library function to clean and tokenize our data so that we can move onto vectorization.
#
# Tokenization is a required task for just about any Natural Language Processing (NLP) task, so great industry-standard tools exist to tokenize things for us, so that we can spend our time on more important tasks without getting bogged down hunting every special symbol or punctuation in a massive dataset. For this analysis, we'll make use of the tokenizer in the amazing `nltk` library, which is short for *Natural Language Tool Kit*.
#
# **NOTE**: `NLTK` requires extra installation methods to be run the first time certain methods are used. If `nltk` throws you an error about needing to install additional packages, follow the instructions in the error message to install the dependencies, and then re-run the cell.
#
# Before we tokenize our job AD plain text files, we'll do only a small manual bit of cleaning. In the cell below, a function that allows us to make every word lowercase, remove newline characters `\n`, and all the following punctuation marks: `",.'?!"` is developed.
#
# Furthermore, this function that not only takes in job AD plain text files having erratic symbols removed but also joins all of the lines into a single string. To sum up, the function, `tokenize_jobAD()`, is utilized to get a fully tokenized version of the job AD. We can test this function on `jobad` to ensure that the function works.

# %%
def tokenize_jobAD(jobad):
    subs = [('.',''),("'",""),('"',''),(',',''),('?',''),('!',''),('\n',''),('\t',''),('\r',''),('|',''),('/',' '),
            ('-',''),('(c)',''),('*',''),('(',''),(')',''),('&',''),(':',''),(';',''),('[',''),(']',''),('\\',''),
            ('â„¢',''),('%',''),('â£',''),('Â£0',''),('Â£',''),('>',''),('<',''),('=',''),('_',''),('__',''),('“',''),
            ('’',''),('–',''),('”',''),('—','')]
    cleaned_jobad = []
    for line in jobad:
        for old, new in subs:
            line = line.replace(old, new).lower()
        cleaned_jobad.append(line)

    tokenized_jobad = ' '.join(cleaned_jobad).split()
    
    return tokenized_jobad

# %%
tokenized_test_jobad = tokenize_jobAD(test_jobad)
print(len(tokenized_test_jobad))
print(tokenized_test_jobad[:100000])
# Out:
# 1019
# ['workopolis', 'logo', 'job', 'title', 'keywords', 'city', 'province', 'menu', 'browse', 'jobs', 'advanced', 'job', 'search', 'français', 'post', 'a', 'job', 'department', 'manager', 'walmart', 'canada', 'richmond', 'hill', 'on', 'apply', 'now', 'leader', 'coach', 'team', 'playerall', 'rolled', 'into', 'one', 'it', 'takes', 'a', 'special', 'kind', 'of', 'person', 'to', 'be', 'a', 'department', 'manager', 'at', 'walmartbecause', 'were', 'every', 'bit', 'as', 'committed', 'to', 'our', 'team', 'culture', 'as', 'we', 'are', 'to', 'our', 'customers', 'no', 'matter', 'the', 'department', 'our', 'managers', 'are', 'friendly', 'confident', 'communicators', 'who', 'know', 'how', 'to', 'get', 'the', 'best', 'out', 'of', 'their', 'teamand', 'theyve', 'got', 'the', 'leadership', 'skills', 'to', 'make', 'people', 'want', 'to', 'perform', 'their', 'best', 'well', 'let', 'you', 'in', 'on', 'a', 'secret', 'we', 'even', 'love', 'and', 'appreciate', 'a', 'bit', 'of', 'a', 'competitive', 'spirit…', 'especially', 'when', 'it', 'comes', 'to', 'hitting', 'new', 'milestones', 'for', 'our', 'charitable', 'initiatives', 'and', 'giving', 'back', 'to', 'our', 'communities', 'the', 'ability', 'to', 'engage', 'and', 'inspire', 'your', 'team', 'to', 'be', 'better', 'than', 'they', 'were', 'yesterday', 'every', 'single', 'day', 'thats', 'a', 'skill', 'worth', 'celebrating', 'whether', 'its', 'motivating', 'their', 'team', 'providing', 'recognition', 'for', 'great', 'work', 'or', '‘wowing', 'our', 'customers…', 'our', 'department', 'managers', 'provide', 'leadership', 'right', 'where', 'the', 'action', 'is', 'and', 'they', 'wouldnt', 'have', 'it', 'any', 'other', 'way', 'our', 'stellar', 'team', 'is', 'seeking', 'managers', 'with', 'the', 'following', 'traits', 'positive', 'attitude', 'confident', 'leader', 'great', 'listening', 'skills', 'strong', 'communication', 'friendly', 'demeanor', 'inquisitive', 'mind', 'energetic', 'outgoing', 'welcoming', 'motivated', 'happy', 'to', 'help', 'at', 'walmart', 'every', 'role', 'mattersin', 'every', 'department', 'were', 'seeking', 'department', 'managers', 'who', 'take', 'pride', 'in', 'what', 'they', 'do', 'and', 'want', 'to', 'inspire', 'others', 'to', 'be', 'their', 'best', 'if', 'you', 'love', 'people', 'and', 'want', 'to', 'work', 'with', 'a', 'winning', 'team', 'that', 'sees', 'every', 'customer', 'as', 'the', 'unique', 'valued', 'individual', 'that', 'they', 'are', 'then', 'we', 'cant', 'wait', 'to', 'meet', 'you', 'realize', 'your', 'potential', 'with', 'walmartapply', 'today', 'department', 'manager', 'roles', 'lead', 'customer', 'service', 'manager', 'meat', 'department', 'manager', 'produce', 'department', 'manager', 'health', 'wellness', 'manager', 'customer', 'value', 'department', 'manager', 'fashion', 'merchandiser', 'department', 'manager', 'day', 'evening', 'fulfillment', 'department', 'manager', 'qualifications', 'a', 'great', 'attitude', 'willingness', 'to', 'lead', 'attention', 'to', 'detail', 'so', 'the', 'store', 'always', 'looks', 'great', 'confidence', 'handling', 'real', 'responsibility', 'willingness', 'to', 'help', 'solve', 'problems', 'your', 'winning', 'smile', 'yes', 'that', 'smile', 'you', 'already', 'have', 'seriously', 'its', 'a', 'great', 'smile', 'look', 'in', 'the', 'mirror', 'see', 'we', 'told', 'you', 'so', 'walmart', 'canada', 'is', 'one', 'of', 'canadas', 'largest', 'employers', 'and', 'is', 'ranked', 'as', 'one', 'of', 'the', 'countrys', 'top', '10', 'most', 'influential', 'brands…', 'but', 'what', 'really', 'sets', 'us', 'apart', 'in', 'the', 'industry', 'is', 'our', 'incredible', 'team', 'were', 'committed', 'to', 'supporting', 'our', 'communities', 'and', 'supporting', 'one', 'another', 'and', 'those', 'values', 'have', 'cultivated', 'a', 'culture', 'where', 'everyone', 'is', 'welcome', 'and', 'each', 'team', 'member', 'feels', 'they', 'truly', 'belong', 'whether', 'youre', 'looking', 'for', 'opportunities', 'to', 'grow', 'your', 'career', 'longterm', 'or', 'simply', 'seekin ...

# %% [markdown]
# Now that we can tokenize our job AD plain text file, we can move onto vectorization.
#
# ## Count Vectorization
#
# Machine Learning algorithms don't understand strings. However, they do understand math, which means they understand vectors and matrices. By Vectorizing the text, we just convert the entire text into a vector, where each element in the vector represents a different word. The vector is the length of the entire vocabulary -- usually, every word that occurs in the English language, or at least every word that appears in our corpus. Any given sentence can then be represented as a vector where all the vector is 1 (or some other value) for each time that word appears in the sentence.
#
# `Count Vectorization` allows us to represent a sentence as a vector, with each element in the vector corresponding to how many times that word is used. Notice that when we vectorize a sentence this way, we lose the order that the words were in. This is the `Bag of Words` approach
#
# In the cell below, create a function that takes in a tokenized, cleaned job AD plain text file and returns a count vectorized representation of it as a Python dictionary (aka: *Sparse Representation*). Add in an optional parameter called vocab that defaults to None. This way, if we are using a vocabulary that contains words not seen in the song, we can still use this function by passing it into the vocab parameter.

# %%
def count_vectorize(jobad, vocab=None):
    if vocab:
        unique_words = vocab
    else:
        unique_words = list(set(jobad))
    
    jobad_dict = {i:0 for i in unique_words}
    
    for word in jobad:
        jobad_dict[word] += 1
    
    return jobad_dict

# %%
test_vectorized = count_vectorize(tokenized_test_jobad)
print(test_vectorized)
# Out:
# {'positive': 2, 'best': 6, 'recognition': 2, 'post': 1, 'as': 10, 'willingness': 4, 'below': 4, 'manager': 19, 'winning': 4, 'us': 4, 'any': 2, 'do': 3, 'older': 2, 'career': 2, 'than': 2, 'about': 1, 'an': 1, 'appreciate': 2, 'were': 8, 'single': 2, 'action': 2, 'grow': 2, 'seriously': 2, '16': 2, 'law': 2, 'way': 2, 'into': 2, 'see': 2, 'employers': 2, 'energetic': 2, 'department': 23, 'the': 28, 'every': 10, 'with': 6, 'told': 2, 'longterm': 2, 'center': 1, 'site': 1, 'walmartbecause': 2, 'everyone': 2, 'take': 2, 'others': 2, 'value': 2, 'each': 2, 'privacy': 2, 'province': 1, 'skills': 4, 'your': 8, 'other': 2, 'handling': 2, 'really': 2, 'customer': 6, 'of': 12, 'theyve': 2, 'wp': 1, 'their': 8, 'workopolis': 2, 'store': 2, 'to': 42, 'know': 2, '‘wowing': 2, 'service': 2, 'welcoming': 2, 'great': 12, 'engage': 2, 'thats': 2, '2021': 1, 'sees': 2, 'communities': 4, 'what': 5, 'committed': 4, 'canada': 3, 'belong': 2, 'valued': 2, 'member': 2, 'job': 6, 'outgoing': 2, 'walmart': 7, 'sets': 2, 'a': 24, 'potential': 2, 'most': 2, 'got': 2, 'brands…': 2, 'customers…': 2, 'already': 2, 'bit': 4, 'produce': 2, 'wellness': 2, 'communicators': 2, 'walmartapply': 2, 'cultivated': 2, 'all': 1, 'how': 2, 'problems': 2, 'terms': 1, 'find': 1, 'responsibility': 2, 'hitting': 2, 'simply': 2, 'cant': 2, 'back': 2, 'applicants': 2, 'solve': 2, 'new': 3, 'individual': 2, 'playerall': 2, 'traits': 2, 'city': 1, 'one': 8, 'look': 2, 'this': 6, 'providing': 2, 'inspire': 4, 'merchandiser': 2, 'matter': 2, 'milestones': 2, 'culture': 4, 'needs': 2, 'on': 3, 'holdings': 1, 'richmond': 1, 'want': 6, 'pride': 2, 'realize': 2, 'person': 2, 'apply': 2, 'security': 1, 'better': 2, 'health': 2, 'logo': 1, 'motivating': 2, 'wouldnt': 2, 'welcome': 2, 'secret': 2, 'online': 1, 'wait': 2, 'roles': 2, 'customers': 2, 'worth': 2, 'inquisitive': 2, 'managers': 8, 'right': 2, 'canadas': 2, 'apart': 2, 'initiatives': 2, 'attention': 2, 'mind': 2, 'if': 6, 'kind': 2, 'or': 6, 'rolled': 2, 'well': 2, 'confident': 4, 'mirror': 2, 'lead': 4, 'whether': 4, 'age': 2, 'jobs': 1, 'have': 6, 'but': 2, 'looks': 2, 'no': 6, 'meat': 2, 'role': 2, 'let': 2, 'giving': 2, 'special': 2, 'accommodate': 2, 'largest': 2, 'another': 2, 'attitude': 4, 'friendly': 4, 'are': 18, 'evening': 2, 'in': 8, 'associates': 2, 'map': 1, 'spirit…': 2, 'unique': 2, 'get': 2, 'detail': 2, 'limited': 1, 'menu': 1, 'ability': 2, 'confidence': 2, 'seeking': 6, 'fashion': 2, 'celebrating': 2, 'français': 1, 'skill': 2, 'charitable': 2, 'countrys': 2, 'you': 10, 'looking': 2, 'ranked': 2, 'incredible': 2, 'listed': 4, 'youll': 1, 'where': 4, 'required': 4, 'provide': 2, 'people': 4, 'youre': 2, 'at': 4, 'strong': 2, 'title': 1, 'who': 4, 'make': 2, 'be': 6, 'when': 2, 'work': 6, 'and': 22, 'will': 2, 'feels': 2, 'always': 2, 'day': 4, 'outlined': 2, 'out': 2, 'partner': 1, 'they': 10, 'qualificationsoutlined': 2, 'for': 11, 'real': 2, 'perform': 2, 'qualifications': 12, 'hill': 1, 'top': 2, 'demeanor': 2, 'truly': 2, 'optional': 2, 'influential': 2, 'today': 2, 'help': 4, 'that': 8, 'then': 2, 'takes': 2, 'it': 6, 'leadership': 4, 'yesterday': 2, 'values': 2, 'indeed': 1, 'competitive': 2, 'following': 2, 'conditions': 1, 'those': 2, 'reserved': 1, 'team': 16, 'motivated': 2, 'industry': 2, 'search': 2, 'we': 8, 'teamand': 2, 'none': 4, 'contact': 1, 'now': 2, 'browse': 1, 'comes': 2, 'its': 4, 'keywords': 1, 'is': 14, 'love': 4, 'stellar': 2, 'listening': 2, 'our': 20, 'happy': 2, 'yes': 2, 'supporting': 4, 'disabilityrelated': 2, 'fulfillment': 2, 'especially': 2, 'rights': 1, 'advanced': 2, '10': 2, 'there': 4, 'place': 4, 'opportunities': 2, 'position': 4, 'so': 4, 'minimum': 6, 'seekers': 1, 'parttime': 2, 'meet': 2, 'coach': 2, 'communication': 2, 'preferred': 6, 'by': 2, 'even': 2, 'mattersin': 2, 'leader': 4, 'smile': 6}

# %% [markdown]
# We've just successfully vectorized the first job AD plain text document! Now, let's look at a more advanced type of vectorization, TF-IDF!

# %%
statesList = ["United States of America","USA","AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS",
              "KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA",
              "RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY","DC","GU","MH","MP","PR","VI","Alabama","Alaska",
              "Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho",
              "Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan",
              "Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","Hampshire","Jersey","Mexico","York",
              "Carolina","Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode","Tennessee","Texas","Utah","Vermone",
              "Virginia","Washington","Wisconsin","Wyoming"]
itList = ["Engineer","Scientist","Developer","Analyst","Operator"]
qaList = ["Qualification","Qualifications","Certification","Certifications"]
euList = ["United Kingdom","UK","EU"]

# %% [markdown]
# check this text job AD text file to ensure it contains any key word(s) in `qaList`

# %%
def qa_usa_Count(filename, tokenized_jobad):
    found_qa = False
    counter_notusa = 0
    counter_qa = 0
    counter_usa = 0
    qaINjobList = []
    qaINusaDict = {}
    
    for eu in euList:
        if eu.lower() in tokenized_jobad.keys():
            counter_notusa += 1
            
    if counter_notusa == 0:
        for qa in qaList:
            if qa.lower() in tokenized_jobad.keys():
                counter_qa += 1
                found_qa = True
                qaINjobList.append(qa)
        if found_qa == True:
            for usa in statesList:
                if usa.lower() in tokenized_jobad.keys():
                    counter_usa += 1
                    qaINusaDict.setdefault(filename, []).append(usa)
            for qa in qaINjobList:
                qaINusaDict.setdefault(filename, []).append(qa)
                
    return counter_qa, counter_usa, qaINusaDict

# %%
qaNums_in_test_vectorized, usaNums_in_test_vectorized, qaDict_in_test_vectorized = qa_usa_Count('92663_2021JAN_jobAD', test_vectorized)
print(qaNums_in_test_vectorized)
print(usaNums_in_test_vectorized)
print(qaDict_in_test_vectorized)
# Out:
# 1
# 2
# {'92663_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}

# %%
def get_list_of_qaJobAds():
    n_0 = 1
    n_1 = 100000
    qaList = []
    for i in range(n_0, n_1):
        qaNums_in_test_vectorized = 0
        usaNums_in_test_vectorized = 0
        filepath = './dat/100k_jobADs/'+str(i)+'_2021JAN_jobAD.txt'
        if (os.path.exists(filepath)):
            filename = filepath.replace('./dat/100k_jobADs/','').replace('.txt','')
            with open(filepath, encoding='utf-8', errors='ignore') as f:
                test_jobad = f.readlines()
            #print(filename)
            tokenized_test_jobad = tokenize_jobAD(test_jobad)
            test_vectorized = count_vectorize(tokenized_test_jobad)
            qaNums_in_test_vectorized, usaNums_in_test_vectorized, qaDics_in_test_vectorized = qa_usa_Count(filename, test_vectorized)
            if (qaNums_in_test_vectorized > 0) and (usaNums_in_test_vectorized > 0):
                qaList.append(qaDics_in_test_vectorized) 
        else:
            continue
                
    return qaList

# %%
print(get_list_of_qaJobAds())
# Out:
# [{'12_2021JAN_jobAD': ['IN', 'Qualifications']}, {'27_2021JAN_jobAD': ['IN', 'OR', 'Qualification']}, {'92_2021JAN_jobAD': ['IN', 'OR', 'Certification']}, {'96_2021JAN_jobAD': ['IN', 'OR', 'Qualification', 'Certification']}, {'129_2021JAN_jobAD': ['IN', 'ME', 'OR', 'Certifications']}, {'210_2021JAN_jobAD': ['ID', 'IN', 'ME', 'MT', 'OR', 'Qualifications']}, {'213_2021JAN_jobAD': ['IN', 'OR', 'Qualification']}, {'221_2021JAN_jobAD': ['AZ', 'IN', 'ME', 'OR', 'Qualifications', 'Certification']}, {'285_2021JAN_jobAD': ['HI', 'IN', 'ME', 'OR', 'California', 'Connecticut', 'Massachusetts', 'Montana', 'Nebraska', 'Jersey', 'Qualifications']}, {'293_2021JAN_jobAD': ['IN', 'OR', 'Certification']}, {'298_2021JAN_jobAD': ['CO', 'IN', 'Qualification']}, {'310_2021JAN_jobAD': ['IN', 'OR', 'Certification']}, {'362_2021JAN_jobAD': ['IN', 'ME', 'OR', 'Certifications']}, {'410_2021JAN_jobAD': ['IN', 'OR', 'Washington', 'Qualifications', 'Certification']}, {'539_2021JAN_jobAD': ['DE', 'IN', 'OR', 'Qualification', 'Qualifications']}, {'574_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'578_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'610_2021JAN_jobAD': ['IN', 'MS', 'OR', 'Mississippi', 'York', 'Pennsylvania', 'Qualifications', 'Certifications']}, {'625_2021JAN_jobAD': ['USA', 'AL', 'IN', 'OR', 'PR', 'Arizona', 'Iowa', 'Nevada', 'Mexico', 'York', 'Tennessee', 'Qualifications', 'Certification', 'Certifications']}, {'629_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'641_2021JAN_jobAD': ['HI', 'ID', 'IN', 'ME', 'OK', 'OR', 'Certification']}, {'683_2021JAN_jobAD': ['IN', 'MS', 'OR', 'Certification']}, {'763_2021JAN_jobAD': ['CO', 'IN', 'NY', 'OR', 'PA', 'York', 'Qualifications']}, {'783_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'786_2021JAN_jobAD': ['IN', 'OR', 'PA', 'Pennsylvania', 'Certifications']}, {'798_2021JAN_jobAD': ['ID', 'IN', 'OR', 'Qualifications']}, {'809_2021JAN_jobAD': ['IN', 'ME', 'MS', 'OR', 'Qualifications']}, {'810_2021JAN_jobAD': ['DE', 'HI', 'ID', 'IN', 'LA', 'ME', 'OK', 'OR', 'Qualification', 'Qualifications', 'Certification']}, {'811_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'833_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'897_2021JAN_jobAD': ['IN', 'OR', 'Illinois', 'Qualifications']}, {'902_2021JAN_jobAD': ['IN', 'ME', 'OR', 'Certification']}, {'909_2021JAN_jobAD': ['IN', 'KS', 'OR', 'Qualifications']}, {'912_2021JAN_jobAD': ['IN', 'OR', 'California', 'Qualifications']}, {'946_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'952_2021JAN_jobAD': ['ID', 'IN', 'OR', 'WA', 'Qualifications', 'Certifications']}, {'971_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'974_2021JAN_jobAD': ['USA', 'AZ', 'AR', 'CA', 'IN', 'OR', 'TX', 'Qualifications']}, {'992_2021JAN_jobAD': ['IN', 'OR', 'Certifications']}, {'993_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'999_2021JAN_jobAD': ['ID', 'IN', 'MS', 'OR', 'Qualifications']}, {'1001_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'1019_2021JAN_jobAD': ['IN', 'MS', 'OR', 'Michigan', 'York', 'Pennsylvania', 'Certifications']}, {'1036_2021JAN_jobAD': ['IN', 'OK', 'OR', 'York', 'Qualifications']}, {'1053_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'1062_2021JAN_jobAD': ['IN', 'OR', 'Certification']}, {'1069_2021JAN_jobAD': ['ID', 'IN', 'ME', 'OK', 'OR', 'Certification', 'Certifications']}, {'1084_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'1102_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'1118_2021JAN_jobAD': ['IN', 'OR', 'Certification']}, {'1146_2021JAN_jobAD': ['IN', 'Qualifications']}, {'1197_2021JAN_jobAD': ['IN', 'Qualifications']}, {'1204_2021JAN_jobAD': ['IN', 'OR', 'Qualifications', 'Certification']}, {'1225_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'1251_2021JAN_jobAD': ['ID', 'IN', 'NJ', 'OR', 'Qualifications', 'Certification']}, {'1370_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'1375_2021JAN_jobAD': ['IN', 'OR', 'Qualifications']}, {'1401_2021JAN_jobAD': ['IN', 'OR', 'Certification']}, {'1427_2021JAN_ ...
